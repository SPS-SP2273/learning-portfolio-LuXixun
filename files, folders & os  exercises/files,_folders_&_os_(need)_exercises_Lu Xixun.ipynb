# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# You are a member of an international team analysing environmental pollution. The project involves ten cities: Cairo, Dhaka, Jakarta, Karachi, Manila, Melbourne, Osaka, Shanghai, Singapore, and Tokyo.
#
# Your task is to process and organise data from various environmental measurements. The provided zip file, os-collaboration-exercise-data.zip, contains all relevant data files for the past year.
#
# **Things to note**
#
# 1. **Data Files**: Each data file is named in the format month-date_city.txt (e.g., may-10_singapore.txt).
# 2. **Data Collection**: Data was recorded sporadically; not all days of each month have corresponding data files. The dates of data collection vary across the cities.
# 3. **Exclusion of Files**: Ignore any non-text files, such as those in .pdf, .png, or .jpg formats.

# %% [markdown]
# ### Task 1
# <br>
# * We like to convert the filename to a more useful numerical format. Specifically, we want to convert month-date-city.txt. (i.e. may-10-singapore.txt) to a mm-dd-city.txt (i.e. 05-10-singapore.txt) format.
#
# * Using the following dictionary (or otherwise), write a snippet of Python code to convert 'oct-08_singapore.txt' to 10-08-singapore.txt.

# %%
filename = 'oct-08_singapore.txt'

month_dictionary = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

split1 = filename.split('_')
month_abbr, day = split1[0].split('-')
new_filename = f"{month_dictionary[month_abbr.lower()]}-{day}-{split1[1]}"

print(new_filename)
# Out:
# 10-08-singapore.txt

# %% [markdown]
# ### Task 2
# <br>
# Incorporate your previous code into a function named rename_my_file(old_file_name) that accepts the old filename as the argument and returns the new file name.

# %%
def rename_my_file(old_file_name):
    filename = old_file_name
    month_dictionary = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    
    split1 = filename.split('_')
    month_abbr, day = split1[0].split('-')
    new_filename = f"{month_dictionary[month_abbr.lower()]}-{day}-{split1[1]}"
    return new_filename

print(rename_my_file('oct-08_singapore.txt'))
# Out:
# 10-08-singapore.txt

# %% [markdown]
# ### Task 3
# <br>
# * Use a for loop to apply the function rename_my_file() to the file list below.

# %%
file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']
# Out:
# ['oct-08_singapore.txt',
#  'jul-10_cairo.txt',
#  'may-15_dhaka.txt',
#  'may-13_cairo.txt',
#  'oct-21_cairo.txt',
#  'jan-10_singapore.txt',
#  'jun-20_tokyo.txt',
#  'aug-06_jakarta.txt',
#  'dec-21_karachi.txt',
#  'jan-01_tokyo.txt']

# %% [markdown]
# Print out your progress in the form `old-file-name ----> new-file-name`

# %%
file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']
for i in range(0, len(file_list), 1):
    print(f'{file_list[i]} ----> {rename_my_file(file_list[i])}')
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# ### Task 4

# %%
import glob
glob.glob('os-collaboration-exercise-data/**', recursive =True)
# Out:
# ['os-collaboration-exercise-data/',
#  'os-collaboration-exercise-data/dec-10_osaka.txt',
#  'os-collaboration-exercise-data/nov-02_melbourne.pdf',
#  'os-collaboration-exercise-data/jul-14_karachi.txt',
#  'os-collaboration-exercise-data/nov-17_osaka.txt',
#  'os-collaboration-exercise-data/oct-08_shanghai.png',
#  'os-collaboration-exercise-data/jul-13_cairo.txt',
#  'os-collaboration-exercise-data/apr-23_jakarta.pdf',
#  'os-collaboration-exercise-data/apr-21_manila.pdf',
#  'os-collaboration-exercise-data/mar-29_manila.pdf',
#  'os-collaboration-exercise-data/aug-26_shanghai.jpg',
#  'os-collaboration-exercise-data/sep-23_cairo.pdf',
#  'os-collaboration-exercise-data/jun-20_manila.png',
#  'os-collaboration-exercise-data/jun-15_manila.txt',
#  'os-collaboration-exercise-data/jun-08_melbourne.jpg',
#  'os-collaboration-exercise-data/aug-20_tokyo.txt',
#  'os-collaboration-exercise-data/sep-05_shanghai.png',
#  'os-collaboration-exercise-data/jun-16_melbourne.txt',
# ...

# %%
import glob

def rename_my_file2(old_file_name):
    filename = old_file_name
    month_dictionary = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    split0 = filename.split('/')
    os = split0[0].split("_")
    split1 = split0[1].split('_')
    month_abbr, day = split1[0].split('-')
    new_filename = f"{split0[0]}/{month_dictionary[month_abbr.lower()]}-{day}-{split1[1]}"
    return new_filename
#print(rename_my_file('os-collaboration-exercise-data/oct-08_singapore.txt'))
    
file_list2 = glob.glob('os-collaboration-exercise-data/**', recursive =True)
file_list3 = [item for item in file_list2 if "txt" in item]

for i in range(0, len(file_list3), 1):
    print(f'{rename_my_file2(file_list3[i])}')
    #print(f'{file_list3[i]}')
    #print(f'{file_list2[i]} ----> {rename_my_file2(file_list2[i])}')
# Out:
# os-collaboration-exercise-data/12-10-osaka.txt
# os-collaboration-exercise-data/07-14-karachi.txt
# os-collaboration-exercise-data/11-17-osaka.txt
# os-collaboration-exercise-data/07-13-cairo.txt
# os-collaboration-exercise-data/06-15-manila.txt
# os-collaboration-exercise-data/08-20-tokyo.txt
# os-collaboration-exercise-data/06-16-melbourne.txt
# os-collaboration-exercise-data/09-05-tokyo.txt
# os-collaboration-exercise-data/06-22-manila.txt
# os-collaboration-exercise-data/04-11-shanghai.txt
# os-collaboration-exercise-data/09-21-singapore.txt
# os-collaboration-exercise-data/02-01-singapore.txt
# os-collaboration-exercise-data/05-09-manila.txt
# os-collaboration-exercise-data/01-20-tokyo.txt
# os-collaboration-exercise-data/01-30-manila.txt
# os-collaboration-exercise-data/06-28-tokyo.txt
# os-collaboration-exercise-data/04-16-shanghai.txt
# os-collaboration-exercise-data/12-07-shanghai.txt
# os-collaboration-exercise-data/11-03-singapore.txt
# ...

# %% [markdown]
# ### Task 5
# Use a for loop to create a folder for each city.
# The list of cities is provided below for your convenience.

# %%
city = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
# Out:
# ['Cairo',
#  'Dhaka',
#  'Jakarta',
#  'Karachi',
#  'Manila',
#  'Melbourne',
#  'Osaka',
#  'Shanghai',
#  'Singapore',
#  'Tokyo']

# %%
import os
os.mkdir('cities')
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for city in ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
    path = os.path.join('cities', city)
    print(f'creating {path}')
    os.mkdir(path)
# Out:
# creating cities/Cairo
# creating cities/Dhaka
# creating cities/Jakarta
# creating cities/Karachi
# creating cities/Manila
# creating cities/Melbourne
# creating cities/Osaka
# creating cities/Shanghai
# creating cities/Singapore
# creating cities/Tokyo

# %% [markdown]
# ### Task 6
# Use glob to list all the files from Cairo.
# Now use a for loop and shutil.copy() to copy all the files related to Cairo to the corresponding folder you created.

# %%
import shutil
file_list2 = glob.glob('os-collaboration-exercise-data/**', recursive =True)
file_list3 = [item for item in file_list2 if "txt" in item]
file_list4 = [item for item in file_list3 if "cairo" in item]
for file in file_list4:
    path = os.path.join('cities', city)
for i in range(0, len(file_list4), 1):
    shutil.copy(file_list4[i], path)
    print(f'copied file to {path}')
glob.glob('cities/Cairo/**', recursive =True)
# Out:
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# copied file to cities/Tokyo
# ...
