# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# # <font color=maroon>Exercise 1

# %%
while True:
    print('*', end='') 
    
#Your Jupyter Notebook should be printing like crazy right now.
#Figure out how to interrupt the proceedings (Kernal).
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %% [markdown]
# <font color=blue> To interupt the proceedings, go to **Kernel-Interupt** at the tool bar.

# %% [markdown]
# # <font color=maroon> Exercise 2

# %%
#Run the following:
print = 'PRINT'

# %%
#Now try:
print('Hello World')

#Yes, you have messed up your print() function
#Fix this by Restarting the Kernal. This will also restart the Python interpreter.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print('Hello World')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# <font color=blue>  To fix this issue, go to **Kernel-Restart** at the tool bar.
